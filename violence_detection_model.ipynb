# %%
import os
import cv2
import numpy as np
from pathlib import Path
from PIL import Image
import matplotlib.pyplot as plt
import seaborn as sns
from tqdm import tqdm
import pandas as pd

import torch
import torch.nn as nn
import torch.optim as optim
from torchvision import models, transforms
from torch.utils.data import Dataset, DataLoader

# Set device (GPU if available)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")
# Out:
# Using device: cpu

# %%
def extract_frames_from_video(video_path, output_folder, frames_per_video=20, resize=(224, 224)):
    cap = cv2.VideoCapture(str(video_path))
    total_frames = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))

    if total_frames == 0:
        print(f"[Warning] No frames in {video_path}")
        return

    interval = max(1, total_frames // frames_per_video)
    video_id = Path(video_path).stem
    out_dir = Path(output_folder) / video_id
    out_dir.mkdir(parents=True, exist_ok=True)

    count = 0
    saved = 0

    while cap.isOpened() and saved < frames_per_video:
        ret, frame = cap.read()
        if not ret:
            break
        if count % interval == 0:
            frame = cv2.resize(frame, resize)
            frame_path = out_dir / f"frame_{saved:03d}.jpg"
            cv2.imwrite(str(frame_path), frame)
            saved += 1
        count += 1

    cap.release()
    print(f"[INFO] Saved {saved} frames for {video_path}")

# %% [markdown]
# ### Cell 4: Process Entire Dataset (Violence & NonViolence)

# %%
def process_dataset(video_dir, output_dir, frames_per_video=20):
    video_dir = Path(video_dir)
    output_dir = Path(output_dir)
    output_dir.mkdir(parents=True, exist_ok=True)

    for label in ["Violence", "NonViolence"]:
        label_dir = video_dir / label
        output_label_dir = output_dir / label
        output_label_dir.mkdir(parents=True, exist_ok=True)

        for video_file in label_dir.glob("*.mp4"):
            extract_frames_from_video(
                video_file, 
                output_label_dir, 
                frames_per_video=frames_per_video
            )

# %% [markdown]
# ### Run Frame Extraction Process

# %%
# Set the path to your downloaded dataset
RAW_VIDEO_PATH = r"C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset"
OUTPUT_FRAME_PATH = "data/frames"

# Run the frame extraction process
process_dataset(RAW_VIDEO_PATH, OUTPUT_FRAME_PATH, frames_per_video=20)
# Out:
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_1.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_10.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_100.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_1000.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_101.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_102.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_103.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_104.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_105.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_106.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_107.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_108.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_109.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_11.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_110.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_111.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_112.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_113.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_114.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_115.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_116.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_117.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_118.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_119.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_12.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_120.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_121.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_122.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_123.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_124.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_125.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_126.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_127.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_128.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_129.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_13.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_130.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_131.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_132.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_133.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_134.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_135.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_136.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_137.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_138.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_139.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_14.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_140.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_141.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_142.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_143.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_144.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_145.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_146.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_147.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_148.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_149.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_15.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_150.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_151.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_152.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_153.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_154.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_155.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_156.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_157.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_158.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_159.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_16.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_160.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_161.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_162.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_163.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_164.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_165.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_166.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_167.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_168.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_169.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_17.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_170.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_171.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_172.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_173.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_174.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_175.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_176.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_177.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_178.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_179.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_18.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_180.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_181.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_182.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_183.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_184.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_185.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_186.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_187.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_188.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_189.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_19.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_190.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_191.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_192.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_193.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_194.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_195.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_196.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_197.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_198.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_199.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_2.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_20.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_200.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_201.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_202.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_203.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_204.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_205.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_206.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_207.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_208.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_209.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_21.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_210.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_211.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_212.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_213.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_214.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_215.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_216.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_217.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_218.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_219.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_22.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_220.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_221.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_222.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_223.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_224.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_225.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_226.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_227.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_228.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_229.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_23.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_230.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_231.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_232.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_233.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_234.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_235.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_236.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_237.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_238.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_239.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_24.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_240.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_241.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_242.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_243.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_244.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_245.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_246.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_247.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_248.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_249.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_25.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_250.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_251.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_252.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_253.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_254.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_255.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_256.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_257.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_258.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_259.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_26.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_260.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_261.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_262.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_263.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_264.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_265.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_266.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_267.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_268.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_269.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_27.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_270.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_271.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_272.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_273.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_274.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_275.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_276.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_277.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_278.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_279.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_28.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_280.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_281.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_282.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_283.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_284.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_285.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_286.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_287.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_288.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_289.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_29.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_290.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_291.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_292.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_293.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_294.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_295.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_296.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_297.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_298.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_299.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_3.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_30.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_300.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_301.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_302.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_303.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_304.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_305.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_306.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_307.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_308.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_309.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_31.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_310.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_311.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_312.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_313.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_314.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_315.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_316.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_317.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_318.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_319.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_32.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_320.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_321.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_322.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_323.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_324.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_325.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_326.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_327.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_328.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_329.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_33.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_330.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_331.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_332.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_333.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_334.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_335.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_336.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_337.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_338.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_339.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_34.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_340.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_341.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_342.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_343.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_344.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_345.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_346.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_347.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_348.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_349.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_35.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_350.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_351.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_352.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_353.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_354.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_355.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_356.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_357.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_358.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_359.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_36.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_360.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_361.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_362.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_363.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_364.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_365.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_366.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_367.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_368.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_369.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_37.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_370.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_371.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_372.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_373.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_374.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_375.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_376.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_377.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_378.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_379.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_38.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_380.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_381.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_382.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_383.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_384.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_385.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_386.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_387.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_388.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_389.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_39.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_390.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_391.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_392.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_393.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_394.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_395.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_396.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_397.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_398.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_399.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_4.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_40.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_400.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_401.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_402.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_403.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_404.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_405.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_406.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_407.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_408.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_409.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_41.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_410.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_411.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_412.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_413.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_414.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_415.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_416.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_417.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_418.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_419.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_42.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_420.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_421.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_422.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_423.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\Violence\V_424.mp4
# ...
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\NonViolence\NV_850.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\NonViolence\NV_851.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\NonViolence\NV_852.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\NonViolence\NV_853.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\NonViolence\NV_854.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\NonViolence\NV_855.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\NonViolence\NV_856.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\NonViolence\NV_857.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\NonViolence\NV_858.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\NonViolence\NV_859.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\NonViolence\NV_86.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\NonViolence\NV_860.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\NonViolence\NV_861.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\NonViolence\NV_862.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\NonViolence\NV_87.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\NonViolence\NV_88.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\NonViolence\NV_89.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\NonViolence\NV_9.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\NonViolence\NV_90.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\NonViolence\NV_91.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\NonViolence\NV_911.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\NonViolence\NV_912.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\NonViolence\NV_913.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\NonViolence\NV_914.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\NonViolence\NV_915.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\NonViolence\NV_916.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\NonViolence\NV_917.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\NonViolence\NV_918.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\NonViolence\NV_919.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\NonViolence\NV_92.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\NonViolence\NV_920.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\NonViolence\NV_921.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\NonViolence\NV_922.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\NonViolence\NV_923.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\NonViolence\NV_924.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\NonViolence\NV_925.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\NonViolence\NV_926.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\NonViolence\NV_927.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\NonViolence\NV_928.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\NonViolence\NV_929.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\NonViolence\NV_93.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\NonViolence\NV_930.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\NonViolence\NV_931.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\NonViolence\NV_932.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\NonViolence\NV_933.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\NonViolence\NV_934.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\NonViolence\NV_935.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\NonViolence\NV_936.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\NonViolence\NV_937.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\NonViolence\NV_938.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\NonViolence\NV_939.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\NonViolence\NV_94.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\NonViolence\NV_940.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\NonViolence\NV_941.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\NonViolence\NV_942.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\NonViolence\NV_943.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\NonViolence\NV_944.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\NonViolence\NV_945.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\NonViolence\NV_946.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\NonViolence\NV_947.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\NonViolence\NV_948.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\NonViolence\NV_949.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\NonViolence\NV_95.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\NonViolence\NV_950.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\NonViolence\NV_951.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\NonViolence\NV_952.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\NonViolence\NV_953.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\NonViolence\NV_954.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\NonViolence\NV_955.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\NonViolence\NV_956.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\NonViolence\NV_957.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\NonViolence\NV_958.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\NonViolence\NV_959.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\NonViolence\NV_96.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\NonViolence\NV_960.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\NonViolence\NV_961.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\NonViolence\NV_962.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\NonViolence\NV_963.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\NonViolence\NV_964.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\NonViolence\NV_965.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\NonViolence\NV_966.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\NonViolence\NV_967.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\NonViolence\NV_968.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\NonViolence\NV_969.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\NonViolence\NV_97.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\NonViolence\NV_970.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\NonViolence\NV_971.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\NonViolence\NV_972.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\NonViolence\NV_973.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\NonViolence\NV_974.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\NonViolence\NV_975.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\NonViolence\NV_976.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\NonViolence\NV_977.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\NonViolence\NV_978.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\NonViolence\NV_979.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\NonViolence\NV_98.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\NonViolence\NV_980.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\NonViolence\NV_981.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\NonViolence\NV_982.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\NonViolence\NV_983.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\NonViolence\NV_984.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\NonViolence\NV_985.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\NonViolence\NV_986.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\NonViolence\NV_987.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\NonViolence\NV_988.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\NonViolence\NV_989.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\NonViolence\NV_99.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\NonViolence\NV_990.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\NonViolence\NV_991.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\NonViolence\NV_992.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\NonViolence\NV_993.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\NonViolence\NV_994.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\NonViolence\NV_995.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\NonViolence\NV_996.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\NonViolence\NV_997.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\NonViolence\NV_998.mp4
# [INFO] Saved 20 frames for C:\Users\adita\Downloads\violence-detection-system\archive\Real Life Violence Dataset\NonViolence\NV_999.mp4

# %%
# Cell 5: Custom PyTorch Dataset for violence frame sequences

class ViolenceDataset(Dataset):
    def __init__(self, root_dir, transform=None):
        self.root_dir = Path(root_dir)
        self.transform = transform
        self.samples = []

        for label in ["Violence", "NonViolence"]:
            label_path = self.root_dir / label
            label_idx = 1 if label == "Violence" else 0

            for video_folder in label_path.iterdir():
                if video_folder.is_dir():
                    frame_paths = sorted(video_folder.glob("*.jpg"))
                    if len(frame_paths) > 0:
                        self.samples.append((frame_paths, label_idx))

    def __len__(self):
        return len(self.samples)

    def __getitem__(self, idx):
        frame_paths, label = self.samples[idx]
        frames = []

        for frame_path in frame_paths:
            image = Image.open(frame_path).convert("RGB")
            if self.transform:
                image = self.transform(image)
            frames.append(image)

        frames = torch.stack(frames)  # Shape: [T, C, H, W]
        return frames, torch.tensor(label, dtype=torch.long)

# %%
# Cell 6: Define transforms and dataloaders

# Image transformations
transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406],  # ImageNet standards
                         std=[0.229, 0.224, 0.225])
])

# Load the dataset
dataset = ViolenceDataset(OUTPUT_FRAME_PATH, transform=transform)

# Split into training and validation sets
train_size = int(0.8 * len(dataset))
val_size = len(dataset) - train_size
train_dataset, val_dataset = torch.utils.data.random_split(dataset, [train_size, val_size])

# Create dataloaders
BATCH_SIZE = 4

train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True, num_workers=2)
val_loader = DataLoader(val_dataset, batch_size=BATCH_SIZE, shuffle=False, num_workers=2)

print(f"Train samples: {len(train_dataset)}")
print(f"Validation samples: {len(val_dataset)}")
# Out:
# Train samples: 1560
# Validation samples: 391

# %%
# Cell 7: Define CNN + LSTM model architecture

class CNNLSTM(nn.Module):
    def __init__(self, hidden_size=256, num_layers=1, num_classes=2):
        super(CNNLSTM, self).__init__()
        
        # Pretrained CNN (ResNet-18 without the final FC layer)
        resnet = models.resnet18(pretrained=True)
        self.cnn = nn.Sequential(*list(resnet.children())[:-1])  # Remove the last FC layer
        self.cnn_output_size = resnet.fc.in_features  # 512 for resnet18

        # Freeze CNN weights (optional, for faster training)
        for param in self.cnn.parameters():
            param.requires_grad = False

        # LSTM to process sequence of CNN features
        self.lstm = nn.LSTM(input_size=self.cnn_output_size,
                            hidden_size=hidden_size,
                            num_layers=num_layers,
                            batch_first=True)

        # Final classifier
        self.classifier = nn.Linear(hidden_size, num_classes)

    def forward(self, x):  # x shape: [B, T, C, H, W]
        B, T, C, H, W = x.size()
        cnn_features = []

        for t in range(T):
            frame = x[:, t, :, :, :]  # Shape: [B, C, H, W]
            with torch.no_grad():  # No gradient for CNN
                feat = self.cnn(frame).squeeze(-1).squeeze(-1)  # Shape: [B, 512]
            cnn_features.append(feat)

        # Stack over time axis
        features = torch.stack(cnn_features, dim=1)  # Shape: [B, T, 512]

        # Pass through LSTM
        lstm_out, _ = self.lstm(features)  # Shape: [B, T, hidden]
        last_out = lstm_out[:, -1, :]  # Take last output
        logits = self.classifier(last_out)  # Shape: [B, num_classes]
        return logits

# %%
# Cell 8: Training function

def train_model(model, train_loader, criterion, optimizer, device):
    model.train()
    total_loss = 0

    for batch in tqdm(train_loader, desc="Training"):
        inputs, labels = batch
        inputs = inputs.to(device)
        labels = labels.to(device)

        optimizer.zero_grad()
        outputs = model(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()

        total_loss += loss.item()

    avg_loss = total_loss / len(train_loader)
    return avg_loss

# %%
# Cell 9: Validation function

def evaluate_model(model, val_loader, criterion, device):
    model.eval()
    total_loss = 0
    correct = 0
    total = 0

    with torch.no_grad():
        for batch in tqdm(val_loader, desc="Validation"):
            inputs, labels = batch
            inputs = inputs.to(device)
            labels = labels.to(device)

            outputs = model(inputs)
            loss = criterion(outputs, labels)
            total_loss += loss.item()

            _, predicted = torch.max(outputs, 1)
            correct += (predicted == labels).sum().item()
            total += labels.size(0)

    avg_loss = total_loss / len(val_loader)
    accuracy = correct / total
    return avg_loss, accuracy

# %%
# Cell 11: Setup ResNet18 as feature extractor
resnet = models.resnet18(weights=models.ResNet18_Weights.DEFAULT)
resnet = nn.Sequential(*list(resnet.children())[:-1])  # Remove FC layer
resnet.eval()
resnet.to(device)

# Preprocessing pipeline
transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406],
                         std=[0.229, 0.224, 0.225])
])

# %%
# Cell 12: Extract features from frames and save as .pt files
from glob import glob
from pathlib import Path
from PIL import Image
from tqdm import tqdm
import cv2
import torch

def extract_and_save_features(frame_root, feature_output_dir):
    frame_root = Path(frame_root)
    feature_output_dir = Path(feature_output_dir)
    feature_output_dir.mkdir(parents=True, exist_ok=True)

    for label in ["Violence", "NonViolence"]:
        label_path = frame_root / label
        out_label_path = feature_output_dir / label
        out_label_path.mkdir(parents=True, exist_ok=True)

        for video_folder in tqdm(sorted(label_path.iterdir()), desc=f"Processing {label}"):
            video_features = []
            for frame_file in sorted(video_folder.glob("*.jpg")):
                # Read frame with OpenCV
                frame = cv2.imread(str(frame_file))
                if frame is None:
                    continue  # Skip unreadable images

                # Convert to RGB and PIL format
                frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
                pil_image = Image.fromarray(frame)  # ✅ Convert to PIL explicitly

                # Apply transform and send to device
                tensor = transform(pil_image).unsqueeze(0).to(device)

                # Extract feature
                with torch.no_grad():
                    feature = resnet(tensor).squeeze().cpu()
                video_features.append(feature)

            if video_features:
                video_features = torch.stack(video_features)  # Shape: [num_frames, 512]
                torch.save(video_features, out_label_path / f"{video_folder.name}.pt")

# Set paths
FRAME_ROOT = "data/frames"
FEATURE_SAVE_DIR = "data/features"

# Run feature extraction
extract_and_save_features(FRAME_ROOT, FEATURE_SAVE_DIR)
# Out:
# Processing Violence: 100%|██████████| 1000/1000 [13:19<00:00,  1.25it/s]
# Processing NonViolence: 100%|██████████| 951/951 [12:02<00:00,  1.32it/s]

# %%
# Cell 13: Dataset for .pt feature tensors

class FeatureDataset(Dataset):
    def __init__(self, feature_dir):
        self.samples = []
        self.labels = []

        for label_idx, label in enumerate(["NonViolence", "Violence"]):
            folder = Path(feature_dir) / label
            for pt_file in folder.glob("*.pt"):
                self.samples.append(pt_file)
                self.labels.append(label_idx)

    def __len__(self):
        return len(self.samples)

    def __getitem__(self, idx):
        feature_path = self.samples[idx]
        features = torch.load(feature_path)  # Shape: [num_frames, 512]
        label = self.labels[idx]
        return features, label

# %%
# Cell 14: DataLoaders for extracted features

from sklearn.model_selection import train_test_split

# Paths
FEATURE_PATH = "data/features"  # This should match your save location

# Full dataset
full_dataset = FeatureDataset(FEATURE_PATH)

# Train/Val split (80/20)
train_idx, val_idx = train_test_split(
    list(range(len(full_dataset))),
    test_size=0.2,
    stratify=full_dataset.labels,
    random_state=42
)

train_subset = torch.utils.data.Subset(full_dataset, train_idx)
val_subset = torch.utils.data.Subset(full_dataset, val_idx)

# Loaders
train_loader = DataLoader(train_subset, batch_size=16, shuffle=True)
val_loader = DataLoader(val_subset, batch_size=16, shuffle=False)

# %%
# Cell 15: LSTM-only model using cached CNN features

class LSTMClassifier(nn.Module):
    def __init__(self, input_size=512, hidden_size=256, num_layers=1, num_classes=2):
        super(LSTMClassifier, self).__init__()
        self.lstm = nn.LSTM(input_size, hidden_size, num_layers, batch_first=True)
        self.fc = nn.Linear(hidden_size, num_classes)

    def forward(self, x):
        # x: [batch_size, sequence_len, 512]
        out, _ = self.lstm(x)  # out: [batch_size, seq_len, hidden]
        out = out[:, -1, :]    # Take last time step
        out = self.fc(out)     # Final classification
        return out

# %%
# Cell 16: Training loop using precomputed CNN features

model = LSTMClassifier().to(device)
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=1e-4)

EPOCHS = 10
train_losses = []
val_losses = []
val_accuracies = []

for epoch in range(EPOCHS):
    print(f"\nEpoch {epoch+1}/{EPOCHS}")

    train_loss = train_model(model, train_loader, criterion, optimizer, device)
    val_loss, val_accuracy = evaluate_model(model, val_loader, criterion, device)

    train_losses.append(train_loss)
    val_losses.append(val_loss)
    val_accuracies.append(val_accuracy)

    print(f"Train Loss: {train_loss:.4f}")
    print(f"Val Loss: {val_loss:.4f} | Val Accuracy: {val_accuracy*100:.2f}%")
# Out:
# Epoch 1/10
# Training: 100%|██████████| 98/98 [00:19<00:00,  5.15it/s]
# Validation: 100%|██████████| 25/25 [00:04<00:00,  5.63it/s]
# Train Loss: 0.4129
# Val Loss: 0.1984 | Val Accuracy: 93.86%
#
# Epoch 2/10
# Training: 100%|██████████| 98/98 [00:02<00:00, 43.75it/s]
# Validation: 100%|██████████| 25/25 [00:00<00:00, 92.00it/s]
# Train Loss: 0.1761
# Val Loss: 0.1471 | Val Accuracy: 94.63%
#
# Epoch 3/10
# Training: 100%|██████████| 98/98 [00:02<00:00, 44.43it/s]
# Validation: 100%|██████████| 25/25 [00:00<00:00, 94.67it/s]
# Train Loss: 0.1123
# Val Loss: 0.1215 | Val Accuracy: 96.42%
#
# Epoch 4/10
# Training: 100%|██████████| 98/98 [00:02<00:00, 44.52it/s]
# Validation: 100%|██████████| 25/25 [00:00<00:00, 90.59it/s]
# Train Loss: 0.0895
# Val Loss: 0.1021 | Val Accuracy: 96.42%
#
# Epoch 5/10
# Training: 100%|██████████| 98/98 [00:02<00:00, 44.93it/s]
# Validation: 100%|██████████| 25/25 [00:00<00:00, 88.62it/s]
# Train Loss: 0.0604
# Val Loss: 0.0897 | Val Accuracy: 97.19%
#
# Epoch 6/10
# Training: 100%|██████████| 98/98 [00:02<00:00, 43.68it/s]
# Validation: 100%|██████████| 25/25 [00:00<00:00, 89.96it/s]
# Train Loss: 0.0381
# Val Loss: 0.0859 | Val Accuracy: 96.93%
#
# Epoch 7/10
# Training: 100%|██████████| 98/98 [00:02<00:00, 44.42it/s]
# Validation: 100%|██████████| 25/25 [00:00<00:00, 94.64it/s]
# Train Loss: 0.0257
# Val Loss: 0.0786 | Val Accuracy: 97.44%
#
# Epoch 8/10
# Training: 100%|██████████| 98/98 [00:02<00:00, 43.64it/s]
# Validation: 100%|██████████| 25/25 [00:00<00:00, 92.72it/s]
# Train Loss: 0.0134
# Val Loss: 0.0809 | Val Accuracy: 97.70%
#
# Epoch 9/10
# Training: 100%|██████████| 98/98 [00:02<00:00, 45.04it/s]
# Validation: 100%|██████████| 25/25 [00:00<00:00, 83.53it/s]
# Train Loss: 0.0071
# Val Loss: 0.0884 | Val Accuracy: 97.95%
#
# Epoch 10/10
# Training: 100%|██████████| 98/98 [00:02<00:00, 45.19it/s]
# Validation: 100%|██████████| 25/25 [00:00<00:00, 91.47it/s]
# Train Loss: 0.0100
# Val Loss: 0.0841 | Val Accuracy: 97.70%

# %%
# Cell 17: Save model
MODEL_SAVE_PATH = "violence_lstm_model.pth"
torch.save(model.state_dict(), MODEL_SAVE_PATH)
print(f"Model saved to {MODEL_SAVE_PATH}")
# Out:
# Model saved to violence_lstm_model.pth

# %%
# Define the CNN model (ResNet18 without the final classifier)
cnn_model = models.resnet18(weights=models.ResNet18_Weights.DEFAULT)
cnn_model = nn.Sequential(*list(cnn_model.children())[:-1])  # Remove classifier
cnn_model.to(device)
cnn_model.eval()
# Out:
# Sequential(
#   (0): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU(inplace=True)
#   (3): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (4): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (5): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (6): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (7): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (8): AdaptiveAvgPool2d(output_size=(1, 1))
# )

# %%
def predict_video(video_path, cnn_model, lstm_model, transform, device, frames_per_video=20):
    from PIL import Image

    # Step 1: Extract frames
    temp_dir = "temp_frames"
    Path(temp_dir).mkdir(exist_ok=True)
    extract_frames_from_video(video_path, temp_dir, frames_per_video=frames_per_video)

    # Step 2: Identify the subdirectory (e.g., temp_frames/V_996)
    subdirs = list(Path(temp_dir).glob("*"))
    if not subdirs:
        print("[ERROR] No extracted frame folders found.")
        return

    frame_folder = subdirs[0]
    frame_paths = sorted(frame_folder.glob("*.jpg"))
    if not frame_paths:
        print("[ERROR] No frames found in extracted folder.")
        return

    # Step 3: Preprocess and extract CNN features
    features = []
    cnn_model.eval()
    with torch.no_grad():
        for frame_path in frame_paths:
            image = Image.open(frame_path).convert("RGB")
            image = transform(image).unsqueeze(0).to(device)
            feature = cnn_model(image).squeeze().cpu()
            features.append(feature)

    if not features:
        print("[ERROR] No frames processed.")
        return

    features = torch.stack(features).unsqueeze(0).to(device)  # Shape: (1, T, F)

    # Step 4: LSTM prediction
    lstm_model.eval()
    with torch.no_grad():
        output = lstm_model(features)
        prediction = torch.argmax(output, dim=1).item()

    # Step 5: Clean up
    for f in frame_paths:
        f.unlink()
    frame_folder.rmdir()
    Path(temp_dir).rmdir()

    print("🔍 Prediction:", "Violence" if prediction == 1 else "Non-Violence")

# %%
predict_video(
    video_path="C:/Users/adita/Downloads/violence-detection-system/NV_981.mp4",
    cnn_model=cnn_model,
    lstm_model=model,
    transform=transform,
    device=device
)
# Out:
# [INFO] Saved 20 frames for C:/Users/adita/Downloads/violence-detection-system/NV_981.mp4
# 🔍 Prediction: Non-Violence
